# %% [markdown]
# - Cosine Similarity: Measures the cosine of the angle between two non-zero vectors and is often used for comparing the similarity between documents or high-dimensional vectors.
#
# - Jaccard Similarity: Computes the size of the intersection divided by the size of the union of two sets. It is commonly used for measuring similarity between sets or binary data.
#
# - Euclidean Distance: Calculates the straight-line distance between two points in a multi-dimensional space. It is frequently used for comparing the similarity between numerical vectors.
#
# - Levenshtein Distance: Measures the minimum number of single-character edits (insertions, deletions, or substitutions) required to change one string into another. It is useful for comparing the similarity or dissimilarity between strings.
#
# - Edit Distance: Similar to Levenshtein Distance, it quantifies the minimum number of operations needed to transform one string into another. It considers insertions, deletions, and substitutions.
#
# - Hamming Distance: Compares two strings of equal length and counts the number of positions at which the corresponding elements are different. It is commonly used for comparing binary strings or strings of fixed length

# %%
import numpy as np
import pandas as pd
import json
import pickle
import os

from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.metrics import jaccard_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler

# %%
data = []

with open('dataset/News_Category_Dataset_v3.json', 'r') as file:
    for line in file:
        data.append(json.loads(line))
        
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#          date
# 0  2022-09-23
# 1  2022-09-23
# 2  2022-09-23
# 3  2022-09-23
# 4  2022-09-22

# %%
df.shape
# Out:
# (209527, 6)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate the text from 'headline', 'category', and 'summary' columns
#text = ' '.join(df['headline']) + ' ' + ' '.join(df['category']) + ' ' + ' '.join(df['short_description'])
#text = ' '.join(df['headline'])
text = df['headline'].values

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(str(text))

# Display the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])
date_range = pd.date_range(start= df['date'].min(), end= df['date'].max())

print(">>"*15,f"[{df['date'].min()} to {df['date'].max()}]","<<"*15)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> [2012-01-28 00:00:00 to 2022-09-23 00:00:00] <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
#df = df.head(500)

# %% [markdown]
# # Model Building

# %%
# Step 2: Preprocess the data (you can customize this based on your requirements)
df['processed_text'] = df['headline'] + ' ' + df['category'] + ' ' + df['short_description']

# Step 3: Vectorize the text data using TF-IDF
vectorizer = TfidfVectorizer(encoding='utf-8', lowercase=True, ngram_range=(1,3))
X = vectorizer.fit_transform(df['processed_text'])


################### Saving Vectorizer ###############

#Save the trained model to a file
model_filename = 'vectorizer.pkl'

os.makedirs('artifacts', exist_ok=True)
file_path =  os.path.join("artifacts", model_filename)

with open(file_path, 'wb') as file:
    pickle.dump(vectorizer,file)

print("Vectorizer saved successfully.")

#######################################################

# Step 4: Calculate cosine similarity
#similarity_matrix = cosine_similarity(X)


# Step 5: Find the most similar data
def find_most_similar_data(query, k=5):
    query_vector = vectorizer.transform([query])
    similarity_scores = cosine_similarity(query_vector, X)
    top_indices = similarity_scores.argsort()[0][::-1][:k]    
    return df.iloc[top_indices]
# Out:
# Vectorizer saved successfully.

# %%
# Step 6: Example usage

#### TEST 1
query_data = input("Enter Query String:\t")
most_similar_data = find_most_similar_data(query_data)

print("\n", ">>"*15, f"Top 5 Matches For Entered Query: {query_data}","<<"*15)
most_similar_data
# Out:
# Enter Query String:	 Book
#  >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Top 5 Matches For Entered Query: Book <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#                                                      link  \
# 133322  https://www.huffingtonpost.com/entry/pccc-eliz...
# 7502    https://www.huffpost.com/entry/how-you-can-boo...
# 151172  https://www.huffingtonpost.com/entry/health-be...
# 164765  https://www.huffingtonpost.com/entry/qantas-ai...
# 73202   https://www.huffingtonpost.com/entry/beyonce-b...
#
#                                                  headline       category  \
# 133322  Progressive Book Club Kicks Off With Elizabeth...       POLITICS
# 7502           Here's How You Can Book A Trip For Just $1         TRAVEL
# 151172  6 Science-Backed Reasons To Go Read A Book Rig...       WELLNESS
# 164765  Qantas Airlines Book Series, 'Stories For Ever...         TRAVEL
# 73202   Break Out That Library Card Because Beyoncé Ha...  ENTERTAINMENT
#
#                                         short_description         authors  \
# 133322                                                       Ashley Alman
# 7502                                 Book now, pay later.   Brittany Nims
# 151172  "It really doesn't matter what book you read, ...  Laura Schocker
# 164765  There is something to be said for reading a go...
# 73202                             The Beyhive book club 🐝    Cole Delbyck
#
#               date                                     processed_text
# 133322  2014-04-22  Progressive Book Club Kicks Off With Elizabeth...
# 7502    2019-01-04  Here's How You Can Book A Trip For Just $1 TRA...
# 151172  2013-10-12  6 Science-Backed Reasons To Go Read A Book Rig...
# 164765  2013-05-21  Qantas Airlines Book Series, 'Stories For Ever...
# 73202   2016-03-09  Break Out That Library Card Because Beyoncé Ha...

# %%
#### TEST 2
query_data = input("Enter Query String:\t")
most_similar_data = find_most_similar_data(query_data)

print("\n", ">>"*15, f"Top 5 Matches For Entered Query: {query_data}","<<"*15)
most_similar_data
# Out:
# Enter Query String:	 Modi
#  >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Top 5 Matches For Entered Query: Modi <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#                                                      link  \
# 130191  https://www.huffingtonpost.com/entry/in-india-...
# 131317  https://www.huffingtonpost.com/entry/india-ele...
# 59314   https://www.huffingtonpost.comhttp://www.huffi...
# 130513  https://www.huffingtonpost.com/entry/narendra-...
# 131891  https://www.huffingtonpost.com/entry/indias-mo...
#
#                                                  headline       category  \
# 130191      In India, Stars Align for Prime Minister Modi       POLITICS
# 131317  Narendra Modi Will Be India's Next Prime Minister      WORLDPOST
# 59314   Social Unity Is Most Important, Says PM Modi O...  THE WORLDPOST
# 130513  Modi Promises 'Glorious Future For India' At I...      WORLDPOST
# 131891  India's Modi on His Best Behavior: Can We Trus...      WORLDPOST
#
#                                         short_description  \
# 130191  Some people would say the stars aligned for Mo...
# 131317
# 59314   In his third independence day address, Prime M...
# 130513
# 131891  Mr. Narendra Modi, the prime ministerial candi...
#
#                                                   authors        date  \
# 130191  Gunjan Bagla, ContributorManagement consultant...  2014-05-29
# 131317                                                     2014-05-16
# 59314                                                      2016-08-15
# 130513                                                     2014-05-26
# 131891  Mike Ghouse, ContributorSpeaker, thinker, writ...  2014-05-09
#
#                                            processed_text
# 130191  In India, Stars Align for Prime Minister Modi ...
# 131317  Narendra Modi Will Be India's Next Prime Minis...
# 59314   Social Unity Is Most Important, Says PM Modi O...
# 130513  Modi Promises 'Glorious Future For India' At I...
# 131891  India's Modi on His Best Behavior: Can We Trus...

# %%
#### TEST 3
query_data = input("Enter Query String:\t")
most_similar_data = find_most_similar_data(query_data)

print("\n", ">>"*15, f"Top 5 Matches For Entered Query: {query_data}","<<"*15)
most_similar_data
# Out:
# Enter Query String:	 Rape
#  >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Top 5 Matches For Entered Query: Rape <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#                                                      link  \
# 114184  https://www.huffingtonpost.com/entry/the-colle...
# 177733  https://www.huffingtonpost.com/entry/syrian-ra...
# 53300   https://www.huffingtonpost.com/entry/overdosin...
# 69698   https://www.huffingtonpost.com/entry/byu-title...
# 63386   https://www.huffingtonpost.com/entry/donald-tr...
#
#                                                  headline  category  \
# 114184     Our 'Rape Problem' Can't Be Solved By Colleges     WOMEN
# 177733                                 Rape Has a Purpose     CRIME
# 53300                          Overdosing on Rape Culture     WOMEN
# 69698   BYU Faces Federal Complaint Over Claim It's Pu...  POLITICS
# 63386            Donald Trump Compares Trade Deal To Rape  POLITICS
#
#                                         short_description  \
# 114184  Particularizing "rape on campus" in the search...
# 177733  Our attempts to pursue equality and opportunit...
# 53300
# 69698   "They’re saying they can’t prove that a rape h...
# 63386   He said the Trans-Pacific Partnership was "jus...
#
#                                                   authors        date  \
# 114184  Soraya Chemaly, ContributorFeminist, writer, a...  2014-11-28
# 177733                Soraya Chemaly, Contributor\nWriter  2013-01-05
# 53300                    Courtney M. Soliday, Contributor  2016-10-22
# 69698                                      Tyler Kingkade  2016-04-19
# 63386                                                      2016-06-29
#
#                                            processed_text
# 114184  Our 'Rape Problem' Can't Be Solved By Colleges...
# 177733  Rape Has a Purpose CRIME Our attempts to pursu...
# 53300                   Overdosing on Rape Culture WOMEN
# 69698   BYU Faces Federal Complaint Over Claim It's Pu...
# 63386   Donald Trump Compares Trade Deal To Rape POLIT...

# %%
#### TEST 4
query_data = input("Enter Query String:\t")
most_similar_data = find_most_similar_data(query_data)

print("\n", ">>"*15, f"Top 5 Matches For Entered Query: {query_data}","<<"*15)
most_similar_data
# Out:
# Enter Query String:	 Data Science
#  >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Top 5 Matches For Entered Query: Data Science <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#                                                      link  \
# 30017   https://www.huffingtonpost.com/entry/what-your...
# 82107   https://www.huffingtonpost.com/entry/getting-d...
# 179627  https://www.huffingtonpost.com/entry/two-higgs...
# 66119   https://www.huffingtonpost.com/entry/how-data-...
# 100362  https://www.huffingtonpost.com/entry/from-comm...
#
#                                                  headline   category  \
# 30017            What Your Data Scientist Wishes You Knew    SCIENCE
# 82107     Getting Down and Dirty With Big Healthcare Data    SCIENCE
# 179627  Two Higgs Bosons? CERN Scientists Revisit Larg...    SCIENCE
# 66119            How data science can help save the world  WORLDPOST
# 100362  From Community College to the White House Admi...    COLLEGE
#
#                                         short_description  \
# 30017   By Daniel Wesley Big data: It’s the topic on e...
# 82107   Humans are fallible. Humans entering data into...
# 179627  The original Higgs data from back in July had ...
# 66119   When the Indonesian government threatened to r...
# 100362  I'm the U.S. Chief Data Scientist -- and I got...
#
#                                                   authors        date  \
# 30017   Young Entrepreneur Council, ContributorInvite-...  2017-07-17
# 82107   Dr. Timothy Imler, ContributorClinical Informa...  2015-11-29
# 179627                                  Jacqueline Howard  2012-12-15
# 66119   Christine Deakers , ContributorWriter, committ...  2016-05-30
# 100362     DJ Patil, ContributorU.S. Chief Data Scientist  2015-05-07
#
#                                            processed_text
# 30017   What Your Data Scientist Wishes You Knew SCIEN...
# 82107   Getting Down and Dirty With Big Healthcare Dat...
# 179627  Two Higgs Bosons? CERN Scientists Revisit Larg...
# 66119   How data science can help save the world WORLD...
# 100362  From Community College to the White House Admi...

# %%
#### TEST 2
query_data = input("Enter Query String:\t")
most_similar_data = find_most_similar_data(query_data)

print("\n", ">>"*15, f"Top 5 Matches For Entered Query: {query_data}","<<"*15)
most_similar_data
# Out:
# Enter Query String:	 Taliban
#  >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Top 5 Matches For Entered Query: Taliban <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#                                                      link  \
# 8555    https://www.huffpost.com/entry/taliban-ambush-...
# 54931   https://www.huffingtonpost.com/entry/afghan-of...
# 125165  https://www.huffingtonpost.com/entry/taliban-m...
# 8415    https://www.huffpost.com/entry/islamic-state-a...
# 66859   https://www.huffingtonpost.com/entry/us-airstr...
#
#                                                  headline       category  \
# 8555    Taliban Militants Ambush And Kill Dozens Of Af...     WORLD NEWS
# 54931   Afghan Officials Report Major Gains In Kunduz ...  THE WORLDPOST
# 125165       Taliban Making Military Gains In Afghanistan      WORLDPOST
# 8415    Islamic State Fighters In Afghanistan Kill At ...     WORLD NEWS
# 66859   Afghan Government Confirms Death Of Taliban Le...  THE WORLDPOST
#
#                                         short_description authors        date  \
# 8555     The three-day Taliban ceasefire ended on Sunday.          2018-06-20
# 54931   But social media accounts linked to the Taliba...          2016-10-04
# 125165                                                             2014-07-26
# 8415    The attack occurred during a prayer ceremony a...          2018-07-17
# 66859   The Taliban have made no official statement bu...          2016-05-21
#
#                                            processed_text
# 8555    Taliban Militants Ambush And Kill Dozens Of Af...
# 54931   Afghan Officials Report Major Gains In Kunduz ...
# 125165  Taliban Making Military Gains In Afghanistan W...
# 8415    Islamic State Fighters In Afghanistan Kill At ...
# 66859   Afghan Government Confirms Death Of Taliban Le...

# %% [raw]
# #import pandas as pd
# #from sklearn.feature_extraction.text import TfidfVectorizer
# #from sklearn.metrics.pairwise import cosine_similarity
#
#
# class EnsembleModel:
#
#     def __init__(self, algorithms):
#         self.algorithms = algorithms
#
#     def fit(self, X):
#         for algorithm in self.algorithms:
#             algorithm(X)
#
#     def predict(self, query_vector, X):
#         predictions = []
#         for algorithm in self.algorithms:
#             predictions.append(algorithm(query_vector,X))
#
#         return np.mean(predictions, axis=0)
#
#
# ################################################
#
#
# # Step 1: Load the data
# #df = pd.read_csv('data.csv')
#
# # Step 2: Preprocess the data (you can customize this based on your requirements)
# df['processed_text'] = df['headline'] + ' ' + df['category'] + ' ' + df['short_description']
#
# # Step 3: Vectorize the text data using TF-IDF
# vectorizer = TfidfVectorizer()
# X = vectorizer.fit_transform(df['processed_text'])
#
# # Step 4: Calculate cosine similarity
# similarity_matrix = cosine_similarity(X)
#
# # Step 5: Create a list of similarity algorithms
# algorithms = [cosine_similarity, euclidean_distances]
#
# # Step 6: Create an ensemble model
# ensemble_model = EnsembleModel(algorithms)
#
# # Step 7: Train the ensemble model
# ensemble_model.fit(X)
#
#
#
#
# # Step 8: Find the most similar data
# def find_most_similar_data(query, k=5):
#     query_vector = vectorizer.transform([query])
#     similarity_scores = ensemble_model.predict(query_vector,X)
#     top_indices = similarity_scores.argsort()[0][::-1][:k]
#     return df.iloc[top_indices]
#
#
# # Step 9: Example usage
# query_data = "sex"
# most_similar_data = find_most_similar_data(query_data)
#
# #print(most_similar_data)
# most_similar_data
